# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# %%
# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
num_epochs = 20
batch_size = 128
learning_rate = 0.001
dropout_prob = 0.5

# Data transformation
transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261)),
])

# Load CIFAR-10 & CIFAR-100
def load_data(dataset='CIFAR10'):
    if dataset == 'CIFAR10':
        trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
        testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
        num_classes = 10
    else:
        trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform)
        testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform)
        num_classes = 100

    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

    return trainloader, testloader, num_classes

# Define the modified AlexNet
class ModifiedAlexNet(nn.Module):
    def __init__(self, num_classes=10, use_dropout=False):
        super(ModifiedAlexNet, self).__init__()
        self.use_dropout = use_dropout
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 192, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(192, 384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.classifier = nn.Sequential(
            nn.Linear(256 * 4 * 4, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_prob if use_dropout else 0),

            nn.Linear(1024, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_prob if use_dropout else 0),

            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Function to train and evaluate the model
def train_and_evaluate(dataset='CIFAR10', use_dropout=False):
    trainloader, testloader, num_classes = load_data(dataset)
    model = ModifiedAlexNet(num_classes, use_dropout).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    train_losses, val_losses, val_accuracies = [], [], []

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for images, labels in trainloader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        train_losses.append(train_loss / len(trainloader))

        # Validation
        model.eval()
        val_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for images, labels in testloader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        val_losses.append(val_loss / len(testloader))
        val_accuracies.append(100 * correct / total)

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accuracies[-1]:.2f}%')

    # Plot Results
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.legend()
    plt.title(f'{dataset} - Loss Curve (Dropout: {use_dropout})')

    plt.subplot(1,2,2)
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.legend()
    plt.title(f'{dataset} - Accuracy Curve (Dropout: {use_dropout})')
    plt.show()

    # Report number of parameters
    num_params = sum(p.numel() for p in model.parameters())
    print(f'Total parameters in Modified AlexNet ({dataset}, Dropout={use_dropout}): {num_params}')

# Run experiments
for dataset in ['CIFAR10', 'CIFAR100']:
    for use_dropout in [False, True]:
        train_and_evaluate(dataset, use_dropout)
# Out:
# ...
# 100%|██████████| 170M/170M [00:04<00:00, 40.0MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch [1/20], Train Loss: 1.7260, Val Loss: 1.4215, Val Acc: 46.74%
# Epoch [2/20], Train Loss: 1.2986, Val Loss: 1.2266, Val Acc: 55.25%
# Epoch [3/20], Train Loss: 1.0897, Val Loss: 1.0087, Val Acc: 64.26%
# Epoch [4/20], Train Loss: 0.9440, Val Loss: 0.8710, Val Acc: 69.68%
# Epoch [5/20], Train Loss: 0.8316, Val Loss: 0.8060, Val Acc: 72.11%
# Epoch [6/20], Train Loss: 0.7512, Val Loss: 0.7913, Val Acc: 72.21%
# Epoch [7/20], Train Loss: 0.6899, Val Loss: 0.7486, Val Acc: 74.18%
# Epoch [8/20], Train Loss: 0.6454, Val Loss: 0.7013, Val Acc: 75.26%
# Epoch [9/20], Train Loss: 0.6061, Val Loss: 0.6574, Val Acc: 77.78%
# Epoch [10/20], Train Loss: 0.5695, Val Loss: 0.6200, Val Acc: 78.73%
# Epoch [11/20], Train Loss: 0.5401, Val Loss: 0.6250, Val Acc: 78.14%
# Epoch [12/20], Train Loss: 0.5174, Val Loss: 0.6285, Val Acc: 79.20%
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
num_epochs = 20
batch_size = 128
learning_rate = 0.001
dropout_prob = 0.5

# Data transformation
transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261)),
])

# Load CIFAR-10 & CIFAR-100
def load_data(dataset='CIFAR10'):
    if dataset == 'CIFAR10':
        trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
        testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
        num_classes = 10
    else:
        trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform)
        testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform)
        num_classes = 100

    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

    return trainloader, testloader, num_classes

class ModifiedVGG11(nn.Module):
    def __init__(self, num_classes=10, use_dropout=False):
        super(ModifiedVGG11, self).__init__()
        self.use_dropout = use_dropout
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.classifier = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_prob if use_dropout else 0),

            nn.Linear(512, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_prob if use_dropout else 0),

            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Function to train and evaluate the model
def train_and_evaluate(dataset='CIFAR10', use_dropout=False):
    trainloader, testloader, num_classes = load_data(dataset)
    model = ModifiedVGG11(num_classes, use_dropout).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    train_losses, val_losses, val_accuracies = [], [], []

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for images, labels in trainloader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        train_losses.append(train_loss / len(trainloader))

        # Validation
        model.eval()
        val_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for images, labels in testloader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        val_losses.append(val_loss / len(testloader))
        val_accuracies.append(100.0 * correct / total)

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accuracies[-1]:.2f}%')

    # Plot Results
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.legend()
    plt.title(f'{dataset} - Loss Curve (Dropout: {use_dropout})')

    plt.subplot(1,2,2)
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.legend()
    plt.title(f'{dataset} - Accuracy Curve (Dropout: {use_dropout})')
    plt.show()

    # Report number of parameters
    num_params = sum(p.numel() for p in model.parameters())
    print(f'Total parameters in Modified AlexNet ({dataset}, Dropout={use_dropout}): {num_params}')

# Run experiments
for dataset in ['CIFAR100', 'CIFAR10']:
    for use_dropout in [True, False]:
        train_and_evaluate(dataset, use_dropout)
# Out:
# ...
# 100%|██████████| 169M/169M [00:04<00:00, 41.1MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch [1/20], Train Loss: 4.4526, Val Loss: 4.2396, Val Acc: 2.82%
# Epoch [2/20], Train Loss: 4.1956, Val Loss: 4.0765, Val Acc: 4.42%
# Epoch [3/20], Train Loss: 4.0361, Val Loss: 3.9415, Val Acc: 7.06%
# Epoch [4/20], Train Loss: 3.9104, Val Loss: 3.7927, Val Acc: 9.47%
# Epoch [5/20], Train Loss: 3.7906, Val Loss: 3.6775, Val Acc: 11.00%
# Epoch [6/20], Train Loss: 3.6827, Val Loss: 3.5881, Val Acc: 13.10%
# Epoch [7/20], Train Loss: 3.5835, Val Loss: 3.4785, Val Acc: 15.18%
# Epoch [8/20], Train Loss: 3.4997, Val Loss: 3.4250, Val Acc: 16.40%
# Epoch [9/20], Train Loss: 3.3958, Val Loss: 3.3147, Val Acc: 18.35%
# Epoch [10/20], Train Loss: 3.3038, Val Loss: 3.2367, Val Acc: 20.71%
# Epoch [11/20], Train Loss: 3.2416, Val Loss: 3.1384, Val Acc: 22.40%
# Epoch [12/20], Train Loss: 3.1671, Val Loss: 3.1079, Val Acc: 22.68%
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
batch_size=8
# Load CIFAR-10 & CIFAR-100
def load_data(dataset='CIFAR10'):
    if dataset == 'CIFAR10':
        trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
        testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
        num_classes = 10
    else:
        trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform)
        testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform)
        num_classes = 100

    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

    return trainloader, testloader, num_classes

# Define a basic ResNet block
class ResNetBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, use_dropout=False):
        super(ResNetBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.use_dropout = use_dropout
        self.dropout = nn.Dropout(0.5) if use_dropout else nn.Identity()

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.dropout(out)
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        return self.relu(out)

# Define ResNet-11 and ResNet-18 architectures
class ResNet(nn.Module):
    def __init__(self, num_blocks, num_classes=10, use_dropout=False):
        super(ResNet, self).__init__()
        self.in_channels = 64
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        self.layer1 = self._make_layer(64, num_blocks[0], stride=1, use_dropout=use_dropout)
        self.layer2 = self._make_layer(128, num_blocks[1], stride=2, use_dropout=use_dropout)
        self.layer3 = self._make_layer(256, num_blocks[2], stride=2, use_dropout=use_dropout)
        self.layer4 = self._make_layer(512, num_blocks[3], stride=2, use_dropout=use_dropout)

        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, out_channels, num_blocks, stride, use_dropout):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(ResNetBlock(self.in_channels, out_channels, stride, use_dropout))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avg_pool(out)
        out = torch.flatten(out, 1)
        return self.fc(out)

# Training function
def train_model(model, train_loader, val_loader, criterion, optimizer, device, epochs=10):
    model.to(device)

    train_losses, val_losses, val_accuracies = [], [], []

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # Validation phase
        model.eval()
        val_loss, correct = 0.0, 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        train_losses.append(running_loss / len(train_loader))
        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(100.0 * correct / total)

        print(f"Epoch {epoch+1}: Train Loss: {train_losses[-1]:.4f}, "
              f"Val Loss: {val_losses[-1]:.4f}, "
              f"Val Accuracy: {val_accuracies[-1]:.2f}%")

    return train_losses, val_losses, val_accuracies

# Define training parameters
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
criterion = nn.CrossEntropyLoss()

# Train and plot for each experiment
for dataset in ['CIFAR10', 'CIFAR100']:
    for use_dropout in [False, True]:
        train_loader, val_loader, num_classes = load_data(dataset)

        # Train ResNet-11
        model_resnet11 = ResNet([1, 1, 1, 1], use_dropout=use_dropout, num_classes=num_classes)
        optimizer_resnet11 = optim.Adam(model_resnet11.parameters(), lr=0.001)
        print(f"\nTraining ResNet-11 on {dataset} with dropout={use_dropout}:")
        train_losses, val_losses, val_accuracies = train_model(model_resnet11, train_loader, val_loader, criterion, optimizer_resnet11, device, epochs=10)

        # Plot losses and accuracy
        epochs_range = range(1, 11)
        plt.figure(figsize=(10, 4))

        plt.subplot(1, 2, 1)
        plt.plot(epochs_range, train_losses, label="Train Loss")
        plt.plot(epochs_range, val_losses, label="Val Loss")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.title(f"Loss Curve ({dataset}, Dropout={use_dropout}, ResNet-11)")
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(epochs_range, val_accuracies, label="Val Accuracy", color="green")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy (%)")
        plt.title(f"Validation Accuracy ({dataset}, Dropout={use_dropout}, ResNet-11)")
        plt.legend()

        plt.show()
# Compare number of parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print("\nNumber of parameters in ResNet-11:", count_parameters(model_resnet11))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# Training ResNet-11 on CIFAR10 with dropout=False:
# Epoch 1: Train Loss: 1.5189, Val Loss: 1.1390, Val Accuracy: 59.14%
# Epoch 2: Train Loss: 1.0209, Val Loss: 0.8687, Val Accuracy: 69.48%
# Epoch 3: Train Loss: 0.8105, Val Loss: 0.6918, Val Accuracy: 75.72%
# Epoch 4: Train Loss: 0.6737, Val Loss: 0.6304, Val Accuracy: 77.97%
# Epoch 5: Train Loss: 0.5863, Val Loss: 0.5487, Val Accuracy: 81.50%
# Epoch 6: Train Loss: 0.5229, Val Loss: 0.4988, Val Accuracy: 82.87%
# Epoch 7: Train Loss: 0.4682, Val Loss: 0.4632, Val Accuracy: 83.94%
# Epoch 8: Train Loss: 0.4314, Val Loss: 0.4640, Val Accuracy: 84.31%
# Epoch 9: Train Loss: 0.3946, Val Loss: 0.4364, Val Accuracy: 84.98%
# Epoch 10: Train Loss: 0.3653, Val Loss: 0.4314, Val Accuracy: 85.54%
# Files already downloaded and verified
# Files already downloaded and verified
#
# Training ResNet-11 on CIFAR10 with dropout=True:
# ...

# %%
batch_size=8
# Data transformation
transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261)),
])


# Define a basic ResNet block
class ResNetBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, use_dropout=False):
        super(ResNetBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.use_dropout = use_dropout
        self.dropout = nn.Dropout(0.5) if use_dropout else nn.Identity()

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.dropout(out)
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        return self.relu(out)

# Define ResNet-11 and ResNet-18 architectures
class ResNet(nn.Module):
    def __init__(self, num_blocks, num_classes=10, use_dropout=False):
        super(ResNet, self).__init__()
        self.in_channels = 64
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        self.layer1 = self._make_layer(64, num_blocks[0], stride=1, use_dropout=use_dropout)
        self.layer2 = self._make_layer(128, num_blocks[1], stride=2, use_dropout=use_dropout)
        self.layer3 = self._make_layer(256, num_blocks[2], stride=2, use_dropout=use_dropout)
        self.layer4 = self._make_layer(512, num_blocks[3], stride=2, use_dropout=use_dropout)

        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, out_channels, num_blocks, stride, use_dropout):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(ResNetBlock(self.in_channels, out_channels, stride, use_dropout))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avg_pool(out)
        out = torch.flatten(out, 1)
        return self.fc(out)

# Load CIFAR-10 & CIFAR-100
def load_data(dataset='CIFAR10'):
    if dataset == 'CIFAR10':
        trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
        testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
        num_classes = 10
    else:
        trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform)
        testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform)
        num_classes = 100

    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

    return trainloader, testloader, num_classes


# Training function
def train_model(model, train_loader, val_loader, criterion, optimizer, device, epochs=10):
    model.to(device)

    train_losses, val_losses, val_accuracies = [], [], []

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # Validation phase
        model.eval()
        val_loss, correct = 0.0, 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        train_losses.append(running_loss / len(train_loader))
        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(100.0 * correct / total)

        print(f"Epoch {epoch+1}: Train Loss: {train_losses[-1]:.4f}, "
              f"Val Loss: {val_losses[-1]:.4f}, "
              f"Val Accuracy: {val_accuracies[-1]:.2f}%")

    return train_losses, val_losses, val_accuracies

criterion = nn.CrossEntropyLoss()
device = 'cuda'

# Train and plot for each experiment
for dataset in ['CIFAR10', 'CIFAR100']:
    for use_dropout in [False, True]:
        train_loader, val_loader, num_classes = load_data(dataset)

        # Train ResNet-18
        model_resnet18 = ResNet([2, 2, 2, 1], use_dropout=use_dropout, num_classes=num_classes)
        optimizer_resnet18 = optim.Adam(model_resnet18.parameters(), lr=0.001)
        print(f"\nTraining ResNet-18 on {dataset} with dropout={use_dropout}:")
        train_losses, val_losses, val_accuracies = train_model(model_resnet18, train_loader, val_loader, criterion, optimizer_resnet18, device, epochs=10)

        # Plot losses and accuracy
        epochs_range = range(1, 11)
        plt.figure(figsize=(10, 4))

        plt.subplot(1, 2, 1)
        plt.plot(epochs_range, train_losses, label="Train Loss")
        plt.plot(epochs_range, val_losses, label="Val Loss")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.title(f"Loss Curve ({dataset}, Dropout={use_dropout}, ResNet-18)")
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(epochs_range, val_accuracies, label="Val Accuracy", color="green")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy (%)")
        plt.title(f"Validation Accuracy ({dataset}, Dropout={use_dropout}, ResNet-18)")
        plt.legend()

        plt.show()
# Compare number of parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print("\nNumber of parameters in ResNet-18:", count_parameters(model_resnet18))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# Training ResNet-18 on CIFAR10 with dropout=False:
# Epoch 1: Train Loss: 1.6093, Val Loss: 1.2503, Val Accuracy: 55.39%
# Epoch 2: Train Loss: 1.0955, Val Loss: 0.9037, Val Accuracy: 68.11%
# Epoch 3: Train Loss: 0.8670, Val Loss: 0.7266, Val Accuracy: 74.28%
# Epoch 4: Train Loss: 0.7177, Val Loss: 0.6216, Val Accuracy: 78.14%
# Epoch 5: Train Loss: 0.6104, Val Loss: 0.5742, Val Accuracy: 79.93%
# Epoch 6: Train Loss: 0.5338, Val Loss: 0.4992, Val Accuracy: 82.82%
# Epoch 7: Train Loss: 0.4771, Val Loss: 0.5141, Val Accuracy: 82.59%
# Epoch 8: Train Loss: 0.4320, Val Loss: 0.4436, Val Accuracy: 84.55%
# Epoch 9: Train Loss: 0.3898, Val Loss: 0.3841, Val Accuracy: 87.02%
# Epoch 10: Train Loss: 0.3604, Val Loss: 0.4204, Val Accuracy: 85.12%
# Files already downloaded and verified
# Files already downloaded and verified
#
# Training ResNet-18 on CIFAR10 with dropout=True:
# ...
